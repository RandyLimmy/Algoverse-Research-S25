# %% [markdown]
# # Step 1: Defining the Case and Ontology Scaffold

# %%
case_links = [
    {
        "case_id": "Case 1",
        "description": "A 3-year-old girl presents with progressive loss of speech and purposeful hand use, "
                       "replaced by frequent hand-wringing movements. Parents report episodes of hyperventilation "
                       "and a decline in motor coordination. Development was normal until around 18 months of age, "
                       "after which regression began gradually.",
        "age_of_onset": "18 months",
        "sex": "Female",
        "hpo_terms": {
            "HP:0002371": "Speech regression",
            "HP:0033044": "Motor Regression",
            "HP:0012171": "Stereotypical hand wringing",
            "HP:0005957": "Breathing dysregulation"
        },
        "ontology_map": {
            "HP:0002371": "Abnormality of speech",
            "HP:0033044": "Abnormality of motor function",
            "HP:0012171": "Abnormality of movement",
            "HP:0005957": "Abnormality of respiratory system"
        },
        "system_map": {
            "Abnormality of speech": "Neurologic",
            "Abnormality of motor function": "Neurologic",
            "Abnormality of movement": "Neurologic",
            "Abnormality of respiratory system": "Respiratory"
        },
        "disease_group_map": {
            "Neurologic": ["Rett Syndrome", "CDKL5 Deficiency", "MECP2 Duplication Syndrome"],
            "Respiratory": ["Congenital Central Hypoventilation Syndrome"]
        },
        "provisional_diagnosis": "Rett Syndrome"
    },

    {
        "case_id": "Case 2",
        "description": "A 15-year-old boy reports progressive muscle weakness, difficulty climbing stairs, and "
                       "drooping of the eyelids. He also notes double vision and increasing fatigue with exertion. "
                       "Examination shows ptosis, ophthalmoplegia, and reduced reflexes.",
        "age_of_onset": "13 years",
        "sex": "Male",
        "hpo_terms": {
            "HP:0000508": "Ptosis",
            "HP:0003546": "Exercise intolerance",
            "HP:0000602": "Ophthalmoplegia",
            "HP:0001324": "Muscle weakness"
        },
        "ontology_map": {
            "HP:0000508": "Abnormality of eyelid morphology",
            "HP:0003546": "Abnormality of metabolism/homeostasis",
            "HP:0000602": "Abnormality of eye movement",
            "HP:0001324": "Abnormality of muscle physiology"
        },
        "system_map": {
            "Abnormality of eyelid morphology": "Neuromuscular",
            "Abnormality of metabolism/homeostasis": "Metabolic/Mitochondrial",
            "Abnormality of eye movement": "Neurologic",
            "Abnormality of muscle physiology": "Musculoskeletal"
        },
        "disease_group_map": {
            "Neuromuscular": ["Kearns-Sayre Syndrome", "MELAS"],
            "Metabolic/Mitochondrial": ["MERRF", "Pearson Syndrome"]
        },
        "provisional_diagnosis": "Kearns-Sayre Syndrome"
    },

    {
        "case_id": "Case 3",
        "description": "A 22-year-old woman presents with daily fevers, a salmon-colored rash that appears during "
                       "the evening, and joint pain affecting her knees and wrists. She reports fatigue and sore "
                       "throat for the past several weeks. Symptoms have not responded to antibiotics.",
        "age_of_onset": "21 years",
        "sex": "Female",
        "hpo_terms": {
            "HP:0001945": "Fever",
            "HP:0025099": "Evanescent rash",
            "HP:0002829": "Arthralgia",
            "HP:0012378": "Fatigue"
        },
        "ontology_map": {
            "HP:0001945": "Constitutional symptom",
            "HP:0025099": "Abnormality of skin morphology",
            "HP:0002829": "Abnormality of the musculoskeletal system",
            "HP:0012378": "Abnormality of metabolism/homeostasis"
        },
        "system_map": {
            "Constitutional symptom": "Immunologic",
            "Abnormality of skin morphology": "Dermatologic",
            "Abnormality of the musculoskeletal system": "Rheumatologic",
            "Abnormality of metabolism/homeostasis": "General/Systemic"
        },
        "disease_group_map": {
            "Immunologic": ["Adult-onset Still’s Disease", "Systemic Lupus Erythematosus"],
            "Rheumatologic": ["Juvenile Idiopathic Arthritis", "Rheumatoid Arthritis"]
        },
        "provisional_diagnosis": "Adult-onset Still’s Disease"
    },

    {
        "case_id": "Case 4",
        "description": "A 45-year-old man is brought to the ED after experiencing confusion, diaphoresis, and "
                       "near-syncope. His glucose level was found to be critically low. Further evaluation revealed "
                       "adrenal insufficiency and a history of kidney stones. Physical exam shows facial angiofibromas.",
        "age_of_onset": "42 years",
        "sex": "Male",
        "hpo_terms": {
            "HP:0001943": "Hypoglycemia",
            "HP:0000846": "Adrenal insufficiency",
            "HP:0000787": "Nephrolithiasis",
            "HP:0009720": "Adenoma Sebaceum"
        },
        "ontology_map": {
            "HP:0001943": "Abnormality of glucose homeostasis",
            "HP:0000846": "Abnormality of endocrine system physiology",
            "HP:0000787": "Abnormality of urinary system",
            "HP:0009720": "Abnormality of skin morphology"
        },
        "system_map": {
            "Abnormality of glucose homeostasis": "Endocrine",
            "Abnormality of endocrine system physiology": "Endocrine",
            "Abnormality of urinary system": "Renal/Urologic",
            "Abnormality of skin morphology": "Dermatologic"
        },
        "disease_group_map": {
            "Endocrine": ["MEN1", "Insulinoma", "Parathyroid Hyperplasia"],
            "Renal/Urologic": ["Nephrolithiasis (MEN-related)"]
        },
        "provisional_diagnosis": "Multiple Endocrine Neoplasia Type 1 (MEN1)"
    },

    {
        "case_id": "Case 5",
        "description": "A 70-year-old woman develops rapidly progressive memory loss, visual disturbances, and "
                       "involuntary jerking movements. Family reports personality changes and periods of unresponsiveness "
                       "over the last few weeks. Neurologic exam shows startle myoclonus.",
        "age_of_onset": "68 years",
        "sex": "Female",
        "hpo_terms": {
            "HP:0000726": "Dementia",
            "HP:0000751": "Personality changes",
            "HP:0001336": "Myoclonus",
            "HP:0002367": "Visual hallucinations"
        },
        "ontology_map": {
            "HP:0000726": "Abnormality of cognition",
            "HP:0000751": "Behavioral abnormality",
            "HP:0001336": "Abnormality of movement",
            "HP:0002367": "Abnormality of visual perception"
        },
        "system_map": {
            "Abnormality of cognition": "Neurologic",
            "Behavioral abnormality": "Psychiatric/Neurologic",
            "Abnormality of movement": "Neurologic",
            "Abnormality of visual perception": "Neurologic"
        },
        "disease_group_map": {
            "Neurologic": ["Creutzfeldt-Jakob Disease", "Autoimmune Encephalitis", "Frontotemporal Dementia"],
            "Psychiatric/Neurologic": ["Paraneoplastic Syndromes", "Rapid-onset Alzheimer’s"]
        },
        "provisional_diagnosis": "Creutzfeldt-Jakob Disease"
    }
]

# %% [markdown]
# Think of this like a hierarchy:
#  Symptom → HPO → Ontology Category → Clinical System
#
#  Ex: "HP:0001276" → "Abnormality of speech" → "Neurologic"

# %% [markdown]
# # Step 2: Construct the Prompt

# %%
def build_zero_shot_prompt(case):
    hpo_lines = "\n".join([f"- {hpo} – {desc}" for hpo, desc in case["hpo_terms"].items()])
    prompt = f"""You are a clinical reasoning assistant tasked with identifying rare disease diagnoses based on phenotypic features.

Please reason step-by-step, following this structure:

Step 1: List the input symptoms and their mapped HPO terms.
Step 2: Map each HPO term to its corresponding clinical system (e.g., neurologic, endocrine, etc.).
Step 3: Group the symptoms into one or more potential disease categories.
Step 4: Generate a list of possible differential diagnoses based on the above grouping.
Step 5: Select the most likely diagnosis.
Step 6: Justify your reasoning using both ontology alignment (HPO/system mapping) and any available external evidence (e.g., prior case reports, OMIM entries, or PubMed abstracts).

Case:
{case['description']}

HPO terms:
{hpo_lines}

Please begin your reasoning."""
    return(prompt)
    #print(prompt)

prompt = build_zero_shot_prompt(case_links[0])
# Out:
# You are a clinical reasoning assistant tasked with identifying rare disease diagnoses based on phenotypic features.
#
# Please reason step-by-step, following this structure:
#
# Step 1: List the input symptoms and their mapped HPO terms.
# Step 2: Map each HPO term to its corresponding clinical system (e.g., neurologic, endocrine, etc.).
# Step 3: Group the symptoms into one or more potential disease categories.
# Step 4: Generate a list of possible differential diagnoses based on the above grouping.
# Step 5: Select the most likely diagnosis.
# Step 6: Justify your reasoning using both ontology alignment (HPO/system mapping) and any available external evidence (e.g., prior case reports, OMIM entries, or PubMed abstracts).
#
# Case:
# ...

# %% [markdown]
# # Add RAG Context

# %%
# 📦 Install dependencies (run this first)
# !pip install requests beautifulsoup4 tqdm

import requests
from bs4 import BeautifulSoup
from tqdm import tqdm
import json
import time

# 🔗 Define your links grouped by case
cases = {
    "Case 1: Rett Syndrome": [
        "https://emedicine.medscape.com/article/916377-clinical",
        "https://www.frontiersin.org/journals/sleep/articles/10.3389/frsle.2024.1373489/full",
        "https://pmc.ncbi.nlm.nih.gov/articles/PMC10029146/",
        "https://www.mayoclinic.org/diseases-conditions/rett-syndrome/symptoms-causes/syc-20377227",
        "https://onlinelibrary.wiley.com/doi/10.1002/cns3.20086"
    ],
    "Case 2: Kearns–Sayre Syndrome": [
        "https://webeye.ophth.uiowa.edu/eyeforum/cases/case24.htm",
        "https://academic.oup.com/omcr/article/2016/3/34/1827090",
        "https://www.thieme-connect.com/products/ejournals/pdf/10.1055/a-2207-7587.pdf",
        "https://bmcophthalmol.biomedcentral.com/articles/10.1186/s12886-021-02224-7",
        "https://www.frontiersin.org/journals/neurology/articles/10.3389/fneur.2023.1320757"
    ],
    "Case 3: Adult-onset Still’s Disease": [
        "https://www.ncbi.nlm.nih.gov/books/NBK538345/",
        "https://pmc.ncbi.nlm.nih.gov/articles/PMC4794578",
        "https://www.sciencedirect.com/science/article/abs/pii/S0896841118303950",
        "https://www.the-rheumatologist.org/article/case-report-persistent-pruritic-plaques-in-adult-onset-stills-disease",
        "https://www.sciencedirect.com/science/article/pii/S0049017221001177"
    ],
    "Case 4: Multiple Endocrine Neoplasia Type 1 (MEN1)": [
        "https://www.ncbi.nlm.nih.gov/books/NBK1538",
        "https://www.frontiersin.org/journals/endocrinology/articles/10.3389/fendo.2019.00339/full",
        "https://www.ncbi.nlm.nih.gov/books/NBK1538",
        "https://ajronline.org/doi/10.2214/AJR.19.22542",
        "https://rarediseases.org/rare-diseases/multiple-endocrine-neoplasia-type-1/"
    ],
    "Case 5: Creutzfeldt-Jakob Disease (CJD)": [
        "https://www.nature.com/articles/s41582-022-00659-0",
        "https://pubmed.ncbi.nlm.nih.gov/24272930/",
        "https://pn.bmj.com/content/17/2/113",
        "https://continuum.aan.com/doi/10.1212/CON.0000000000001089",
        "https://www.sciencedirect.com/science/article/pii/S1930043325001062"
    ]
}

# 🧹 Scraping function using BeautifulSoup
def extract_text(url):
    try:
        headers = {"User-Agent": "Mozilla/5.0"}
        response = requests.get(url, headers=headers, timeout=10)
        soup = BeautifulSoup(response.text, "html.parser")
        paragraphs = soup.find_all("p")
        return "\n".join(p.get_text() for p in paragraphs if len(p.get_text()) > 40)
    except Exception as e:
        print(f"[ERROR] {url}: {e}")
        return ""

# 🧠 Build the document list
documents = []
doc_id = 1
for case, links in tqdm(cases.items()):
    for url in links:
        text = extract_text(url)
        documents.append({
            "id": f"doc_{doc_id}",
            "case": case,
            "url": url,
            "text": text,
            "source": "web"
        })
        doc_id += 1
        time.sleep(1)  # be polite to servers

# 💾 Save as JSONL
with open("rag_corpus.jsonl", "w") as f:
    for doc in documents:
        f.write(json.dumps(doc) + "\n")

print("✅ Done! Saved to rag_corpus.jsonl")
# Out:
# ...
# 100%|██████████| 5/5 [00:45<00:00,  9.13s/it]
# ✅ Done! Saved to rag_corpus.jsonl

# %%
# !pip install langchain openai chromadb tiktoken -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 87.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 18.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 67.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 80.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.6/201.6 kB 15.2 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain-google-genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.8/47.8 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 57.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.6.15
#     Uninstalling google-ai-generativelanguage-0.6.15:
#       Successfully uninstalled google-ai-generativelanguage-0.6.15
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-generativeai 0.8.5 requires google-ai-generativelanguage==0.6.15, but you have google-ai-generativelanguage 0.6.18 which is incompatible.
# ...

# %%
# !pip install -U langchain-community -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 61.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.5 MB/s eta 0:00:00

# %%
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyAtr_n8913XCpV0BiX_YEY-fM8deHWjfbE"

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_community.vectorstores import Chroma
from langchain.schema import Document
import json

# 📂 Load your scraped corpus
with open("rag_corpus.jsonl", "r") as f:
    raw_docs = [json.loads(line) for line in f]

# ✂️ Chunking each document into manageable pieces

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=150)
all_chunks = []

for doc in raw_docs:
    # ✅ Skip any doc that is empty or improperly formatted
    if not doc.get("text") or not isinstance(doc["text"], str) or len(doc["text"].strip()) < 10:
        continue

    chunks = text_splitter.create_documents(
        texts=[doc["text"]],
        metadatas=[{
            "source": doc["url"],
            "case": doc["case"],
            "doc_id": doc["id"]
        }]
    )
    all_chunks.extend(chunks)

print(f"✅ Total Chunks: {len(all_chunks)}")


# ⚙️ Embed and store in Chroma
embedding_model = GoogleGenerativeAIEmbeddings(model="models/embedding-001")  # or switch to Gemini if needed
vectorstore = Chroma.from_documents(all_chunks, embedding_model, persist_directory="rag_chroma_db")

# 💾 Save for reuse
vectorstore.persist()
print("🎉 Embeddings saved to rag_chroma_db/")
# Out:
# ✅ Total Chunks: 715
# 🎉 Embeddings saved to rag_chroma_db/

# %%
from langchain.vectorstores import Chroma
from langchain.chains import RetrievalQA
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import PromptTemplate
from langchain_google_genai import GoogleGenerativeAIEmbeddings

# 🧠 Load your vectorstore
vectorstore = Chroma(persist_directory="rag_chroma_db", embedding_function=embedding_model)
retriever = vectorstore.as_retriever(search_kwargs={"k": 5})  # retrieve top 5 chunks

# 💬 Setup Gemini chat model (you can change model name if needed)
llm = ChatGoogleGenerativeAI(model="gemini-1.5-pro-latest", temperature=0.3)

# 🧾 Define your prompt template
rag_prompt_template = PromptTemplate(
    input_variables=["case_description", "hpo_terms", "retrieved_context"],
    template="""
You are a clinical reasoning assistant tasked with identifying rare disease diagnoses based on phenotypic features.

Please reason step-by-step, following this structure:

Step 1: List the input symptoms and their mapped HPO terms.
Step 2: Map each HPO term to its corresponding clinical system (e.g., neurologic, endocrine, etc.).
Step 3: Group the symptoms into one or more potential disease categories.
Step 4: Generate a list of possible differential diagnoses based on the above grouping.
Step 5: Select the most likely diagnosis.
Step 6: Justify your reasoning using both ontology alignment (HPO/system mapping) and any available external evidence (e.g., prior case reports, OMIM entries, or PubMed abstracts).

Case:
{case_description}

HPO terms:
{hpo_terms}

Relevant context:
{retrieved_context}

Please begin your reasoning.
"""
)

# 🧠 Function to retrieve and run
def run_rag_diagnosis(case):
    case_description = case["description"]
    hpo_terms = "\n".join([f"- {k} – {v}" for k, v in case["hpo_terms"].items()])

    # Retrieve relevant documents
    related_docs = retriever.get_relevant_documents(case_description)
    retrieved_context = "\n---\n".join([doc.page_content for doc in related_docs])

    # Build final prompt
    final_prompt = rag_prompt_template.format(
        case_description=case_description,
        hpo_terms=hpo_terms,
        retrieved_context=retrieved_context
    )

    print("🔍 Final Prompt:")
    print(final_prompt)

    # Get model response
    response = llm.invoke(final_prompt)
    print("\n🧠 Model Output:\n", response.content)

# 🚀 Run on Case 1
run_rag_diagnosis(case_links[0])
# Out:
# 🔍 Final Prompt:
#
# You are a clinical reasoning assistant tasked with identifying rare disease diagnoses based on phenotypic features.
#
# Please reason step-by-step, following this structure:
#
# Step 1: List the input symptoms and their mapped HPO terms.
# Step 2: Map each HPO term to its corresponding clinical system (e.g., neurologic, endocrine, etc.).
# Step 3: Group the symptoms into one or more potential disease categories.
# Step 4: Generate a list of possible differential diagnoses based on the above grouping.
# Step 5: Select the most likely diagnosis.
# Step 6: Justify your reasoning using both ontology alignment (HPO/system mapping) and any available external evidence (e.g., prior case reports, OMIM entries, or PubMed abstracts).
#
# Case:
# ...

# %% [markdown]
# # Send To LLM API

# %%
# !pip install google-generativeai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 17.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.6.18
#     Uninstalling google-ai-generativelanguage-0.6.18:
#       Successfully uninstalled google-ai-generativelanguage-0.6.18
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-google-genai 2.1.8 requires google-ai-generativelanguage<0.7.0,>=0.6.18, but you have google-ai-generativelanguage 0.6.15 which is incompatible.
# ...

# %%
import google.generativeai as genai

genai.configure(api_key=os.environ["GOOGLE_API_KEY"])

def generate_diagnosis_with_gemini(prompt):
    model = genai.GenerativeModel("gemini-pro")
    response = model.generate_content(prompt)
    return response.text

def run_rag_diagnosis(case_dict, k=5):
    # Build initial prompt
    prompt = build_zero_shot_prompt(case_dict)

    # Retrieve top k relevant documents from Chroma
    retriever = vectorstore.as_retriever(search_kwargs={"k": k})
    results = retriever.invoke(prompt)

    # Extract raw text from retrieved documents
    context_snippets = [doc.page_content for doc in results]

    # Append RAG context to the prompt
    full_prompt = add_retrieval_context(prompt, context_snippets)

    # Generate response using Gemini
    print("📡 Sending to Gemini...")
    response = generate_diagnosis_with_gemini(full_prompt)
    print("🧠 Response:\n", response)

run_rag_diagnosis(case_links[0])  # or any case like cases[2]
# Out:
# You are a clinical reasoning assistant tasked with identifying rare disease diagnoses based on phenotypic features.
#
# Please reason step-by-step, following this structure:
#
# Step 1: List the input symptoms and their mapped HPO terms.
# Step 2: Map each HPO term to its corresponding clinical system (e.g., neurologic, endocrine, etc.).
# Step 3: Group the symptoms into one or more potential disease categories.
# Step 4: Generate a list of possible differential diagnoses based on the above grouping.
# Step 5: Select the most likely diagnosis.
# Step 6: Justify your reasoning using both ontology alignment (HPO/system mapping) and any available external evidence (e.g., prior case reports, OMIM entries, or PubMed abstracts).
#
# Case:
# ...

# %% [markdown]
# # Store Outputs in Structured Format

# %% [markdown]
# # Save as JSON for Evaluation

# %% [markdown]
# ## Build Helper Functions for Evaluation (Top K Accuracy, Evidence Grounding Ration, Hallucination Rate by Step, etc.)
